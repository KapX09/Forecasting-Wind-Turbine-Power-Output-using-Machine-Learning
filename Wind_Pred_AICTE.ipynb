# %% [markdown]
# ### Forecasting Wind Turbine Power Output

# %% [markdown]
# #### Week 1

# %% [markdown]
# ##### Data
# The Wind Turbine Scada Dataset (year 2018).

# %%
# Importing Dataset
import pandas as pd
turbine_data = pd.read_csv('WindTurbine_Data.csv')
turbine_data.head(10)
# Out:
#           Date/Time  LV ActivePower (kW)  Wind Speed (m/s)  \
# 0  01 01 2018 00:00           380.047791          5.311336
# 1  01 01 2018 00:10           453.769196          5.672167
# 2  01 01 2018 00:20           306.376587          5.216037
# 3  01 01 2018 00:30           419.645904          5.659674
# 4  01 01 2018 00:40           380.650696          5.577941
# 5  01 01 2018 00:50           402.391998          5.604052
# 6  01 01 2018 01:00           447.605713          5.793008
# 7  01 01 2018 01:10           387.242188          5.306050
# 8  01 01 2018 01:20           463.651215          5.584629
# 9  01 01 2018 01:30           439.725708          5.523228
#
#    Theoretical_Power_Curve (KWh)  Wind Direction (°)
# 0                     416.328908          259.994904
# 1                     519.917511          268.641113
# 2                     390.900016          272.564789
# 3                     516.127569          271.258087
# 4                     491.702972          265.674286
# 5                     499.436385          264.578613
# 6                     557.372363          266.163605
# 7                     414.898179          257.949493
# 8                     493.677652          253.480698
# 9                     475.706783          258.723785

# %% [markdown]
# ##### Preprocessing

# %%
turbine_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50530 entries, 0 to 50529
# Data columns (total 5 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Date/Time                      50530 non-null  datetime64[ns]
#  1   LV ActivePower (kW)            50530 non-null  float64
#  2   Wind Speed (m/s)               50530 non-null  float64
#  3   Theoretical_Power_Curve (KWh)  50530 non-null  float64
#  4   Wind Direction (°)             50530 non-null  float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 1.9 MB

# %%
# Find and remove Null values
turbine_data.isnull().sum()
# Out:
# Date/Time                        0
# LV ActivePower (kW)              0
# Wind Speed (m/s)                 0
# Theoretical_Power_Curve (KWh)    0
# Wind Direction (°)               0
# dtype: int64

# %%
# Converting Date/time same format.
turbine_data['Date/Time'] = pd.to_datetime(turbine_data['Date/Time'], format='%d %m %Y %H:%M')
# keeping it time ordered
turbine_data = turbine_data.sort_values(by='Date/Time')

display(turbine_data.head())
# Out:
#             Date/Time  LV ActivePower (kW)  Wind Speed (m/s)  \
# 0 2018-01-01 00:00:00           380.047791          5.311336
# 1 2018-01-01 00:10:00           453.769196          5.672167
# 2 2018-01-01 00:20:00           306.376587          5.216037
# 3 2018-01-01 00:30:00           419.645904          5.659674
# 4 2018-01-01 00:40:00           380.650696          5.577941
#
#    Theoretical_Power_Curve (KWh)  Wind Direction (°)
# 0                     416.328908          259.994904
# 1                     519.917511          268.641113
# 2                     390.900016          272.564789
# 3                     516.127569          271.258087
# 4                     491.702972          265.674286

# %%
# Duplicate values
turbine_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
# # Unit check
# turbine_data['Wind Speed (m/s)'].unique()
# turbine_data['Wind Direction (°)'].unique()
# turbine_data['Theoretical_Power_Curve (KWh)'].unique()
# turbine_data['LV ActivePower (kW)'].unique()
# # norneeded cause they are all cleaned.
# Not required of Scalling either

# %% [markdown]
# ##### Feature Engineering

# %%
# Converting
